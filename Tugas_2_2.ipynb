# %% [markdown]
# <a href="https://colab.research.google.com/github/ibnumuhammad/Tugas_2_Datamining/blob/main/Tugas_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 2
#
#
# Nama :
# - Ahmad Faiz Rusydi(2101202062)
# - Ibnu Muhammad Hamri (2101202077)

# %%
 from google.colab import drive
 import pandas as pd

 drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Penggalian Data/Tugas 2
# Out:
# /content/drive/MyDrive/Penggalian Data/Tugas 2

# %%
ls
# Out:
# customers.csv    products.csv         Tugas_2.ipynb
# gasstations.csv  transactions_1k.csv  yearmonth.csv

# %%
customers = pd.read_csv('customers.csv')
gasstations = pd.read_csv('gasstations.csv')
products = pd.read_csv('products.csv')
yearmonth = pd.read_csv('yearmonth.csv')
transactions_1k = pd.read_csv('transactions_1k.csv')
display(customers, gasstations, products, yearmonth, transactions_1k)
# Out:
#        CustomerID Segment Currency
# 0               3     SME      EUR
# 1               5     LAM      EUR
# 2               6     SME      EUR
# 3               7     LAM      EUR
# 4               9     SME      EUR
# ...           ...     ...      ...
# 32456       53307     SME      CZK
# 32457       53309     SME      CZK
# 32458       53311     SME      CZK
# 32459       53313     SME      CZK
# 32460       53314     SME      CZK
#
# [32461 rows x 3 columns]
#       GasStationID  ChainID Country          Segment
# 0               44       13     CZE  Value for money
# 1               45        6     CZE          Premium
# 2               46       23     CZE            Other
# 3               47       33     CZE          Premium
# 4               48        4     CZE          Premium
# ...            ...      ...     ...              ...
# 5711          5768        3     CZE            Other
# 5712          5769      153     SVK            Other
# ...

# %%
df = pd.merge(transactions_1k, customers)
df.rename(columns={'Segment':'Segment_x'},inplace=True)
df
# Out:
#      TransactionID        Date      Time  ...   Price  Segment_x  Currency
# 0                1  2012-08-24  09:41:00  ...  672.64        KAM       CZK
# 1               75  2012-08-24  06:53:00  ...  133.83        KAM       CZK
# 2              102  2012-08-24  15:51:00  ...  138.92        KAM       CZK
# 3              111  2012-08-24  17:47:00  ...  144.01        KAM       CZK
# 4              119  2012-08-24  16:41:00  ...  548.40        KAM       CZK
# ..             ...         ...       ...  ...     ...        ...       ...
# 995            986  2012-08-26  13:16:00  ...   39.50        LAM       CZK
# 996            989  2012-08-26  12:27:00  ...  279.38        SME       CZK
# 997            993  2012-08-26  08:02:00  ...  664.43        KAM       CZK
# 998            995  2012-08-26  09:45:00  ...  312.00        LAM       CZK
# 999            996  2012-08-26  13:04:00  ...  612.86        LAM       CZK
#
# [1000 rows x 11 columns]

# %%
df1 = pd.merge(df, gasstations)
df1.rename(columns={'Segment':'Segment_y'},inplace=True)
df1
# Out:
#      TransactionID        Date      Time  ...  ChainID  Country        Segment_y
# 0                1  2012-08-24  09:41:00  ...        4      CZE          Premium
# 1                2  2012-08-24  10:03:00  ...        4      CZE          Premium
# 2                3  2012-08-24  10:03:00  ...        4      CZE          Premium
# 3               75  2012-08-24  06:53:00  ...        4      CZE          Premium
# 4               69  2012-08-24  06:11:00  ...        4      CZE          Premium
# ..             ...         ...       ...  ...      ...      ...              ...
# 995            936  2012-08-26  08:12:00  ...       35      CZE         Discount
# 996            939  2012-08-26  03:13:00  ...       23      CZE            Other
# 997            948  2012-08-26  09:40:00  ...       13      CZE  Value for money
# 998            993  2012-08-26  08:02:00  ...       33      CZE          Premium
# 999            996  2012-08-26  13:04:00  ...       35      CZE         Discount
#
# ...

# %%
df2 = pd.merge(df1, products)
df2
# Out:
#      TransactionID        Date      Time  ...  Country        Segment_y   Description
# 0                1  2012-08-24  09:41:00  ...      CZE          Premium         Nafta
# 1                2  2012-08-24  10:03:00  ...      CZE          Premium         Nafta
# 2               76  2012-08-24  08:40:00  ...      CZE          Premium         Nafta
# 3               77  2012-08-24  09:18:00  ...      CZE          Premium         Nafta
# 4               78  2012-08-24  10:12:00  ...      CZE          Premium         Nafta
# ..             ...         ...       ...  ...      ...              ...           ...
# 995            264  2012-08-24  09:50:00  ...      SVK          Premium  Umývanie voz
# 996            277  2012-08-24  13:53:00  ...      SVK          Premium  Umývanie voz
# 997            272  2012-08-24  11:11:00  ...      SVK          Premium  Autokozmetik
# 998            482  2012-08-25  04:49:00  ...      CZE  Value for money    Knihy,nov.
# ...

# %%
yearmonth.rename(columns={'Date':'Date_z'},inplace=True)
df3 = pd.merge(df2,yearmonth)
df3
# Out:
#        TransactionID        Date      Time  ...  Description  Date_z  Consumption
# 0                  1  2012-08-24  09:41:00  ...        Nafta  201201    166428.05
# 1                  1  2012-08-24  09:41:00  ...        Nafta  201202    182846.43
# 2                  1  2012-08-24  09:41:00  ...        Nafta  201203    186840.11
# 3                  1  2012-08-24  09:41:00  ...        Nafta  201204    146470.89
# 4                  1  2012-08-24  09:41:00  ...        Nafta  201205    151979.24
# ...              ...         ...       ...  ...          ...     ...          ...
# 17650            587  2012-08-25  06:49:00  ...    Additivum  201307     64110.55
# 17651            587  2012-08-25  06:49:00  ...    Additivum  201308     60220.93
# 17652            587  2012-08-25  06:49:00  ...    Additivum  201309     65186.50
# 17653            587  2012-08-25  06:49:00  ...    Additivum  201310     76535.55
# ...

# %%
df3.notna().sum()
# Out:
# TransactionID    17655
# Date             17655
# Time             17655
# CustomerID       17655
# CardID           17655
# GasStationID     17655
# ProductID        17655
# Amount           17655
# Price            17655
# Segment_x        17655
# Currency         17655
# ChainID          17655
# Country          17655
# Segment_y        17655
# Description      17655
# Date_z           17655
# Consumption      17655
# dtype: int64

# %% [markdown]
# #Top List 5 Customer

# %%
df3.CustomerID.value_counts().head()
# Out:
# 19182    380
# 31543    360
# 7626     252
# 33094    220
# 6266     200
# Name: CustomerID, dtype: int64

# %% [markdown]
# #Top 5 List Gas Stations

# %%
df3.GasStationID.value_counts().head()
# Out:
# 448     220
# 1155    218
# 48      202
# 636     190
# 3748    184
# Name: GasStationID, dtype: int64

# %% [markdown]
# #Top 5 List  Jenis Produk

# %%
df2.ProductID.value_counts().head()
# Out:
# 2      523
# 5      239
# 317     43
# 15      41
# 9       27
# Name: ProductID, dtype: int64

# %% [markdown]
# #Deskripsi Statistik Transaksi

# %%
transactions_1k.groupby('Date').describe()
# Out:
#            TransactionID                          ...   Price
#                    count        mean         std  ...     50%      75%      max
# Date                                              ...
# 2012-08-23          10.0  164.500000  175.423456  ...  619.44  795.095  1994.71
# 2012-08-24         492.0  260.065041  158.448665  ...  332.45  615.395  5762.49
# 2012-08-25         425.0  708.637647  133.902758  ...  370.38  600.850  3600.84
# 2012-08-26          73.0  955.232877   26.181270  ...  437.03  675.520  2303.75
#
# [4 rows x 56 columns]

# %% [markdown]
# #Best Time Transaction

# %%
df3.Time.sum()
# Out:
# '09:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0009:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0016:41:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0009:25:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0014:54:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0016:23:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0018:18:0005:37:0005:37:0005:37:0005:37:0005:37
# ...
